# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option("display.max_rows", 100, "display.max_columns", 1000)

# %% [markdown]
# # Import Data

# %%
# Membaca dataset dengan separator koma
nyc_data = pd.read_csv('/content/drive/MyDrive/Dataset_Tubes_VDI/dataset_TSMC2014_NYC.csv', sep=',')
tokyo_data = pd.read_csv('/content/drive/MyDrive/Dataset_Tubes_VDI/dataset_TSMC2014_TKY.csv', sep=',')

# %% [markdown]
# ## Checking Data

# %%
nyc_data.head(10)
# Out:
#    userId                   venueId           venueCategoryId  \
# 0     470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1     979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2      69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3     395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4      87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# 5     484  4b5b981bf964a520900929e3  4bf58dd8d48988d118951735
# 6     642  4ab966c3f964a5203c7f20e3  4bf58dd8d48988d1e0931735
# 7     292  4d0cc47f903d37041864bf55  4bf58dd8d48988d12b951735
# 8     428  4ce1863bc4f6a35d8bd2db6c  4bf58dd8d48988d103941735
# 9     877  4be319b321d5a59352311811  4bf58dd8d48988d10a951735
#
#          venueCategory   latitude  longitude  timezoneOffset  \
# 0  Arts & Crafts Store  40.719810 -74.002581            -240
# 1               Bridge  40.606800 -74.044170            -240
# 2       Home (private)  40.716162 -73.883070            -240
# ...

# %%
tokyo_data.head(10)
# Out:
#    userId                   venueId           venueCategoryId  \
# 0    1541  4f0fd5a8e4b03856eeb6c8cb  4bf58dd8d48988d10c951735
# 1     868  4b7b884ff964a5207d662fe3  4bf58dd8d48988d1d1941735
# 2     114  4c16fdda96040f477cc473a5  4d954b0ea243a5684a65b473
# 3     868  4c178638c2dfc928651ea869  4bf58dd8d48988d118951735
# 4    1458  4f568309e4b071452e447afe  4f2a210c4b9023bd5841ed28
# 5    1541  4b83b207f964a5202c0d31e3  4bf58dd8d48988d1f8941735
# 6    1541  4ea281c302d529c116a57755  4d954b0ea243a5684a65b473
# 7     114  4b3eae5cf964a520b4a025e3  4bf58dd8d48988d129951735
# 8    1635  4cca7bd67965b60c80f0858a  4bf58dd8d48988d162941735
# 9    2033  4b5c7671f964a520083129e3  4bf58dd8d48988d1d1941735
#
#             venueCategory   latitude   longitude  timezoneOffset  \
# 0          Cosmetics Shop  35.705101  139.619590             540
# 1   Ramen /  Noodle House  35.715581  139.800317             540
# 2       Convenience Store  35.714542  139.480065             540
# ...

# %% [markdown]
# ### Check for missing values

# %%
# Check for missing values
print("Jumlah nilai hilang di NYC:")
print(nyc_data.isnull().sum())
print("\nJumlah nilai hilang di Tokyo:")
print(tokyo_data.isnull().sum())
# Out:
# Jumlah nilai hilang di NYC:
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64
#
# Jumlah nilai hilang di Tokyo:
# userId             0
# venueId            0
# venueCategoryId    0
# venueCategory      0
# latitude           0
# longitude          0
# timezoneOffset     0
# utcTimestamp       0
# dtype: int64

# %% [markdown]
# > Data udah bersihh

# %% [markdown]
# ### Check for duplicates

# %% [markdown]
# #### NYC Data

# %%
# Check for duplicates
print("Jumlah duplikat di NYC sebelum dihapus:", nyc_data.duplicated().sum())

# Drop duplicates
nyc_data.drop_duplicates(inplace=True)

# Verify that duplicates have been removed
print("Jumlah duplikat di NYC setelah dihapus:", nyc_data.duplicated().sum())
# Out:
# Jumlah duplikat di NYC sebelum dihapus: 250
# Jumlah duplikat di NYC setelah dihapus: 0

# %% [markdown]
# #### Tokyo Data

# %%
# Check for duplicates
print("Jumlah duplikat di Tokyo sebelum dihapus:", tokyo_data.duplicated().sum())

# Drop duplicates
tokyo_data.drop_duplicates(inplace=True)

# Verify that duplicates have been removed
print("Jumlah duplikat di Tokyo setelah dihapus:", tokyo_data.duplicated().sum())
# Out:
# Jumlah duplikat di Tokyo sebelum dihapus: 577
# Jumlah duplikat di Tokyo setelah dihapus: 0

# %% [markdown]
# ## Check The Statistical number from the Data

# %%
print(nyc_data.describe())
# Out:
#               userId       latitude      longitude  timezoneOffset
# count  227178.000000  227178.000000  227178.000000   227178.000000
# mean      535.289016      40.754053     -73.974556     -253.402266
# std       305.405197       0.072461       0.086207       43.230340
# min         1.000000      40.550852     -74.274766     -420.000000
# 25%       287.000000      40.718330     -74.000633     -240.000000
# 50%       523.000000      40.747745     -73.983479     -240.000000
# 75%       793.000000      40.778371     -73.945709     -240.000000
# max      1083.000000      40.988332     -73.683825      660.000000

# %%
print(tokyo_data.describe())
# Out:
#               userId       latitude      longitude  timezoneOffset
# count  573126.000000  573126.000000  573126.000000   573126.000000
# mean     1123.945481      35.676370     139.713220      539.966709
# std       658.522650       0.058959       0.074693        5.454116
# min         1.000000      35.510185     139.470878     -480.000000
# 25%       557.000000      35.650417     139.691390      540.000000
# 50%      1120.000000      35.685867     139.719307      540.000000
# 75%      1681.000000      35.704023     139.767101      540.000000
# max      2293.000000      35.867150     139.912593      600.000000

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# ### Convert utcTimestamp to datetime format

# %%
# Mengonversi kolom 'utcTimestamp' ke format datetime
nyc_data['utcTimestamp'] = pd.to_datetime(nyc_data['utcTimestamp'], format="%a %b %d %H:%M:%S %z %Y", errors='coerce')
tokyo_data['utcTimestamp'] = pd.to_datetime(tokyo_data['utcTimestamp'], format="%a %b %d %H:%M:%S %z %Y", errors='coerce')

# Ekstraksi fitur waktu
nyc_data['Year'] = nyc_data['utcTimestamp'].dt.year
nyc_data['Month'] = nyc_data['utcTimestamp'].dt.month
nyc_data['Hour'] = nyc_data['utcTimestamp'].dt.hour

tokyo_data['Year'] = tokyo_data['utcTimestamp'].dt.year
tokyo_data['Month'] = tokyo_data['utcTimestamp'].dt.month
tokyo_data['Hour'] = tokyo_data['utcTimestamp'].dt.hour

# %%
if nyc_data['utcTimestamp'].isnull().any():
    print("Ada nilai yang tidak dapat dikonversi menjadi datetime.")

# Ekstraksi fitur waktu
nyc_data['Year'] = nyc_data['utcTimestamp'].dt.year
nyc_data['Month'] = nyc_data['utcTimestamp'].dt.month
nyc_data['Hour'] = nyc_data['utcTimestamp'].dt.hour

# Menampilkan beberapa baris untuk melihat fitur baru yang ditambahkan
print("NYC Data dengan fitur waktu tambahan:")
print(nyc_data[['utcTimestamp', 'Year', 'Month', 'Hour']].head(10))

if tokyo_data['utcTimestamp'].isnull().any():
    print("Ada nilai yang tidak dapat dikonversi menjadi datetime.")

# Ekstraksi fitur waktu
nyc_data['Year'] = nyc_data['utcTimestamp'].dt.year
nyc_data['Month'] = nyc_data['utcTimestamp'].dt.month
nyc_data['Hour'] = nyc_data['utcTimestamp'].dt.hour

# Menampilkan beberapa baris untuk melihat fitur baru yang ditambahkan
print("Tokyo Data dengan fitur waktu tambahan:")
print(nyc_data[['utcTimestamp', 'Year', 'Month', 'Hour']].head(10))
# Out:
# NYC Data dengan fitur waktu tambahan:
#                utcTimestamp  Year  Month  Hour
# 0 2012-04-03 18:00:09+00:00  2012      4    18
# 1 2012-04-03 18:00:25+00:00  2012      4    18
# 2 2012-04-03 18:02:24+00:00  2012      4    18
# 3 2012-04-03 18:02:41+00:00  2012      4    18
# 4 2012-04-03 18:03:00+00:00  2012      4    18
# 5 2012-04-03 18:04:00+00:00  2012      4    18
# 6 2012-04-03 18:04:38+00:00  2012      4    18
# 7 2012-04-03 18:04:42+00:00  2012      4    18
# 8 2012-04-03 18:06:18+00:00  2012      4    18
# 9 2012-04-03 18:06:19+00:00  2012      4    18
# Tokyo Data dengan fitur waktu tambahan:
#                utcTimestamp  Year  Month  Hour
# 0 2012-04-03 18:00:09+00:00  2012      4    18
# 1 2012-04-03 18:00:25+00:00  2012      4    18
# 2 2012-04-03 18:02:24+00:00  2012      4    18
# 3 2012-04-03 18:02:41+00:00  2012      4    18
# 4 2012-04-03 18:03:00+00:00  2012      4    18
# 5 2012-04-03 18:04:00+00:00  2012      4    18
# ...

# %%
nyc_data
# Out:
#         userId                   venueId           venueCategoryId  \
# 0          470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1          979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2           69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3          395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4           87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# ...        ...                       ...                       ...
# 227423     688  3fd66200f964a52000e71ee3  4bf58dd8d48988d1e7931735
# 227424     560  4bca32ff0687ef3be789dbcc  4bf58dd8d48988d16c941735
# 227425     945  50a77716e4b0b5a9492f6f56  4bf58dd8d48988d103941735
# 227426     671  4514efe0f964a520e7391fe3  4bf58dd8d48988d11d941735
# 227427     942  4a1e0ca0f964a520bf7b1fe3  4bf58dd8d48988d116941735
#
#               venueCategory   latitude  longitude  timezoneOffset  \
# 0       Arts & Crafts Store  40.719810 -74.002581            -240
# ...

# %%
tokyo_data
# Out:
#         userId                   venueId           venueCategoryId  \
# 0         1541  4f0fd5a8e4b03856eeb6c8cb  4bf58dd8d48988d10c951735
# 1          868  4b7b884ff964a5207d662fe3  4bf58dd8d48988d1d1941735
# 2          114  4c16fdda96040f477cc473a5  4d954b0ea243a5684a65b473
# 3          868  4c178638c2dfc928651ea869  4bf58dd8d48988d118951735
# 4         1458  4f568309e4b071452e447afe  4f2a210c4b9023bd5841ed28
# ...        ...                       ...                       ...
# 573698     326  4bab3456f964a5204d993ae3  4bf58dd8d48988d1e9931735
# 573699     853  4b559c09f964a520efe827e3  4bf58dd8d48988d129951735
# 573700    1502  5101e81ee4b020384100b0a5  4bf58dd8d48988d1dc931735
# 573701     408  4bbc5648afe1b7134743304b  4bf58dd8d48988d16e941735
# 573702    1050  4b5a7486f964a52027c628e3  4bf58dd8d48988d10d951735
#
#                 venueCategory   latitude   longitude  timezoneOffset  \
# 0              Cosmetics Shop  35.705101  139.619590             540
# ...

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
# Normalisasi Nama Kategori
nyc_data['venueCategory'] = nyc_data['venueCategory'].str.strip().str.replace(' +', ' ')
tokyo_data['venueCategory'] = tokyo_data['venueCategory'].str.strip().str.replace(' +', ' ')

# %%
nyc_data
# Out:
#         userId                   venueId           venueCategoryId  \
# 0          470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1          979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2           69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3          395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4           87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
# ...        ...                       ...                       ...
# 227423     688  3fd66200f964a52000e71ee3  4bf58dd8d48988d1e7931735
# 227424     560  4bca32ff0687ef3be789dbcc  4bf58dd8d48988d16c941735
# 227425     945  50a77716e4b0b5a9492f6f56  4bf58dd8d48988d103941735
# 227426     671  4514efe0f964a520e7391fe3  4bf58dd8d48988d11d941735
# 227427     942  4a1e0ca0f964a520bf7b1fe3  4bf58dd8d48988d116941735
#
#               venueCategory   latitude  longitude  timezoneOffset  \
# 0       Arts & Crafts Store  40.719810 -74.002581            -240
# ...

# %% [markdown]
# ## Visualisasi Data

# %% [markdown]
# ### Bagaimana distribusi check-in per kategori tempat di New York dan Tokyo?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
  def plot_checkin_distribution(city_data, city_name):
      plt.figure(figsize=(10, 6))
      category_counts = city_data['venueCategory'].value_counts().head(10)
      sns.barplot(
          x=category_counts.values,
          y=category_counts.index,
          palette="coolwarm"
      )
      plt.title(f"Distribusi Check-In per Kategori di {city_name}", fontsize=18, fontweight='bold', pad=20)
      plt.xlabel("Jumlah Check-In", fontsize=14, labelpad=10)
      plt.ylabel("Kategori Tempat", fontsize=14, labelpad=10)
      plt.xticks(fontsize=12)
      plt.yticks(fontsize=12)
      plt.tight_layout()
      plt.show()

  plot_checkin_distribution(nyc_data, "New York City")
  plot_checkin_distribution(tokyo_data, "Tokyo")
# Out:
# <ipython-input-19-b8a89e865539>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-19-b8a89e865539>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Kapan waktu-waktu puncak check-in di masing-masing kota?

# %%
def plot_peak_hours(city_data, city_name):
    hourly_counts = city_data['Hour'].value_counts().sort_index()

    plt.figure(figsize=(12, 7))
    sns.set_theme(style="whitegrid")

    # Plot utama dengan gradien warna
    line = sns.lineplot(
        x=hourly_counts.index,
        y=hourly_counts.values,
        marker="o",
        linewidth=2.5,
        color="#4CAF50",
        zorder=2
    )

    # Area berbayang di bawah kurva
    plt.fill_between(
        hourly_counts.index,
        hourly_counts.values,
        color="#a8ddb5",
        alpha=0.3
    )

    # Sorot jam dengan check-in tertinggi
    peak_hour = hourly_counts.idxmax()
    peak_value = hourly_counts.max()
    plt.scatter(peak_hour, peak_value, color="red", s=150, zorder=3, label=f"Puncak: {peak_hour}:00 ({peak_value} check-in)")

    # Tambahkan keterangan
    plt.title(f"Jam-Jam Puncak Check-In di {city_name}", fontsize=20, fontweight='bold', pad=20)
    plt.xlabel("Jam (24 Jam)", fontsize=14, labelpad=10)
    plt.ylabel("Jumlah Check-In", fontsize=14, labelpad=10)
    plt.xticks(range(0, 24), fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12, loc='upper right', frameon=True, fancybox=True, shadow=True, borderpad=1)

    # Highlight grid
    plt.grid(axis='both', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

# Contoh panggilan
plot_peak_hours(tokyo_data, "Tokyo")
plot_peak_hours(nyc_data, "New York City")

# %% [markdown]
# ### Bagaimana pola check-in berdasarkan waktu dalam sehari di New York vs Tokyo?

# %%
def plot_daily_patterns(nyc_data, tokyo_data):
    plt.figure(figsize=(10, 6))
    sns.histplot(nyc_data['Hour'], kde=True, label="New York", color="#4caf50", bins=24, alpha=0.7)
    sns.histplot(tokyo_data['Hour'], kde=True, label="Tokyo", color="#2196f3", bins=24, alpha=0.7)
    plt.title("Pola Check-In Berdasarkan Waktu Dalam Sehari", fontsize=18, fontweight='bold', pad=20)
    plt.xlabel("Jam (24 Jam)", fontsize=14, labelpad=10)
    plt.ylabel("Jumlah Check-In", fontsize=14, labelpad=10)
    plt.xticks(range(0, 24), fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12)
    plt.tight_layout()
    plt.show()

# Contoh panggilan
plot_daily_patterns(nyc_data, tokyo_data)

# %% [markdown]
# ### Area mana saja yang menjadi hotspot atau lokasi dengan konsentrasi check-in tertinggi di Tokyo dan NYC?
#
# Visualisasi User Heatmap

# %% [markdown]
# #### NYC

# %%
import folium
from folium.plugins import MarkerCluster

# %%
# Filter data for user ID 868
user_data = nyc_data[nyc_data['userId'] == 470]

# Create a map centered around the mean latitude and longitude of the user's locations
map_center = [user_data['latitude'].mean(), user_data['longitude'].mean()]
user_map = folium.Map(location=map_center, zoom_start=12)

# Create a heatmap
heat_data = [[row['latitude'], row['longitude']] for index, row in user_data.iterrows()]
folium.plugins.HeatMap(heat_data).add_to(user_map)

# Add markers for each location with venueCategory as the popup
for index, row in user_data.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=row['venueCategory'],
        tooltip=row['venueCategory']
    ).add_to(user_map)


# Display the map
user_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Tokyo

# %%
# Filter data for user ID 868
user_data = tokyo_data[tokyo_data['userId'] == 868]

# Create a map centered around the mean latitude and longitude of the user's locations
map_center = [user_data['latitude'].mean(), user_data['longitude'].mean()]
user_map = folium.Map(location=map_center, zoom_start=12)

# Create a heatmap
heat_data = [[row['latitude'], row['longitude']] for index, row in user_data.iterrows()]
folium.plugins.HeatMap(heat_data).add_to(user_map)

# Add markers for each location with venueCategory as the popup
for index, row in user_data.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=row['venueCategory'],
        tooltip=row['venueCategory']
    ).add_to(user_map)


# Display the map
user_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Merged the Dataset for the Dashboard

# %%
# prompt: can you help me merged the datasets into 1, but before that, make 1 column that labeled them differently tokyo for tokyo dataset and nyc for nyc dataset

# Add a column to identify the city
nyc_data['city'] = 'nyc'
tokyo_data['city'] = 'tokyo'

# Concatenate the dataframes
merged_data = pd.concat([nyc_data, tokyo_data], ignore_index=True)

# Display the merged dataframe
print(merged_data.head())
# Out:
#    userId                   venueId           venueCategoryId  \
# 0     470  49bbd6c0f964a520f4531fe3  4bf58dd8d48988d127951735
# 1     979  4a43c0aef964a520c6a61fe3  4bf58dd8d48988d1df941735
# 2      69  4c5cc7b485a1e21e00d35711  4bf58dd8d48988d103941735
# 3     395  4bc7086715a7ef3bef9878da  4bf58dd8d48988d104941735
# 4      87  4cf2c5321d18a143951b5cec  4bf58dd8d48988d1cb941735
#
#          venueCategory   latitude  longitude  timezoneOffset  \
# 0  Arts & Crafts Store  40.719810 -74.002581            -240
# 1               Bridge  40.606800 -74.044170            -240
# 2       Home (private)  40.716162 -73.883070            -240
# 3       Medical Center  40.745164 -73.982519            -240
# 4           Food Truck  40.740104 -73.989658            -240
#
#                utcTimestamp  Year  Month  Hour           lat_bin  \
# 0 2012-04-03 18:00:09+00:00  2012      4    18  (40.638, 40.726]
# 1 2012-04-03 18:00:25+00:00  2012      4    18   (40.55, 40.638]
# ...

# %%
# Display only the Tokyo dataset from the merged dataframe
tokyo_data_subset = merged_data[merged_data['city'] == 'tokyo']
tokyo_data_subset
# Out:
#         userId                   venueId           venueCategoryId  \
# 227178    1541  4f0fd5a8e4b03856eeb6c8cb  4bf58dd8d48988d10c951735
# 227179     868  4b7b884ff964a5207d662fe3  4bf58dd8d48988d1d1941735
# 227180     114  4c16fdda96040f477cc473a5  4d954b0ea243a5684a65b473
# 227181     868  4c178638c2dfc928651ea869  4bf58dd8d48988d118951735
# 227182    1458  4f568309e4b071452e447afe  4f2a210c4b9023bd5841ed28
# ...        ...                       ...                       ...
# 800299     326  4bab3456f964a5204d993ae3  4bf58dd8d48988d1e9931735
# 800300     853  4b559c09f964a520efe827e3  4bf58dd8d48988d129951735
# 800301    1502  5101e81ee4b020384100b0a5  4bf58dd8d48988d1dc931735
# 800302     408  4bbc5648afe1b7134743304b  4bf58dd8d48988d16e941735
# 800303    1050  4b5a7486f964a52027c628e3  4bf58dd8d48988d10d951735
#
#                 venueCategory   latitude   longitude  timezoneOffset  \
# 227178         Cosmetics Shop  35.705101  139.619590             540
# ...

# %%
merged_data.tail(10)
# Out:
#         userId                   venueId           venueCategoryId  \
# 800294    1067  4b4d45eff964a520d7cf26e3  4bf58dd8d48988d129951735
# 800295     384  4b93049bf964a520192f34e3  4bf58dd8d48988d16e941735
# 800296    2277  4b82669cf964a5209ed130e3  4bf58dd8d48988d172941735
# 800297     806  4bcfc90a9854d13ac6cff64d  4bf58dd8d48988d196941735
# 800298    2277  4b56c4c5f964a520c41a28e3  4bf58dd8d48988d1fd931735
# 800299     326  4bab3456f964a5204d993ae3  4bf58dd8d48988d1e9931735
# 800300     853  4b559c09f964a520efe827e3  4bf58dd8d48988d129951735
# 800301    1502  5101e81ee4b020384100b0a5  4bf58dd8d48988d1dc931735
# 800302     408  4bbc5648afe1b7134743304b  4bf58dd8d48988d16e941735
# 800303    1050  4b5a7486f964a52027c628e3  4bf58dd8d48988d10d951735
#
#                venueCategory   latitude   longitude  timezoneOffset  \
# 800294         Train Station  35.560684  139.723730             540
# 800295  Fast Food Restaurant  35.655037  139.796652             540
# ...

# %%
# Drop the specified columns
filtered_data = merged_data.drop(columns=["venueId", "venueCategoryId", "lat_bin", "lon_bin"])


# Check the result
print(filtered_data.head())
# Out:
#    userId        venueCategory   latitude  longitude  timezoneOffset  \
# 0     470  Arts & Crafts Store  40.719810 -74.002581            -240
# 1     979               Bridge  40.606800 -74.044170            -240
# 2      69       Home (private)  40.716162 -73.883070            -240
# 3     395       Medical Center  40.745164 -73.982519            -240
# 4      87           Food Truck  40.740104 -73.989658            -240
#
#                utcTimestamp  Year  Month  Hour city
# 0 2012-04-03 18:00:09+00:00  2012      4    18  nyc
# 1 2012-04-03 18:00:25+00:00  2012      4    18  nyc
# 2 2012-04-03 18:02:24+00:00  2012      4    18  nyc
# 3 2012-04-03 18:02:41+00:00  2012      4    18  nyc
# 4 2012-04-03 18:03:00+00:00  2012      4    18  nyc

# %%
filtered_data
# Out:
#         userId         venueCategory   latitude   longitude  timezoneOffset  \
# 0          470   Arts & Crafts Store  40.719810  -74.002581            -240
# 1          979                Bridge  40.606800  -74.044170            -240
# 2           69        Home (private)  40.716162  -73.883070            -240
# 3          395        Medical Center  40.745164  -73.982519            -240
# 4           87            Food Truck  40.740104  -73.989658            -240
# ...        ...                   ...        ...         ...             ...
# 800299     326           Music Venue  35.656939  139.702518             540
# 800300     853         Train Station  35.858740  139.657286             540
# 800301    1502              Tea Room  35.701748  139.771216             540
# 800302     408  Fast Food Restaurant  35.670465  139.768348             540
# 800303    1050           Record Shop  35.704069  139.579496             540
#
# ...

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800304 entries, 0 to 800303
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userId          800304 non-null  int64
#  1   venueCategory   800304 non-null  object
#  2   latitude        800304 non-null  float64
#  3   longitude       800304 non-null  float64
#  4   timezoneOffset  800304 non-null  int64
#  5   utcTimestamp    800304 non-null  datetime64[ns, UTC]
#  6   Year            800304 non-null  int32
#  7   Month           800304 non-null  int32
#  8   Hour            800304 non-null  int32
#  9   city            800304 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), int32(3), int64(2), object(2)
# memory usage: 51.9+ MB

# %%
print(filtered_data.columns)
# Out:
# Index(['userId', 'venueCategory', 'latitude', 'longitude', 'timezoneOffset',
#        'utcTimestamp', 'Year', 'Month', 'Hour', 'city'],
#       dtype='object')

# %%
# Rename columns to avoid blank or problematic headers
filtered_data.columns = [f"Column_{i}" if not col else col for i, col in enumerate(filtered_data.columns)]

# %%
filtered_data.columns = filtered_data.columns.str.strip()

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800304 entries, 0 to 800303
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userId          800304 non-null  int64
#  1   venueCategory   800304 non-null  object
#  2   latitude        800304 non-null  float64
#  3   longitude       800304 non-null  float64
#  4   timezoneOffset  800304 non-null  int64
#  5   utcTimestamp    800304 non-null  datetime64[ns, UTC]
#  6   Year            800304 non-null  int32
#  7   Month           800304 non-null  int32
#  8   Hour            800304 non-null  int32
#  9   city            800304 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), int32(3), int64(2), object(2)
# memory usage: 51.9+ MB

# %% [markdown]
# # Tweak the data

# %% [markdown]
# ### Export Data

# %%
import pandas as pd


# Assigning the index column name
filtered_data.index.name = "index"

# Ensuring no empty headers
filtered_data.columns = [col if col else f"Column_{i}" for i, col in enumerate(filtered_data.columns)]

# Parsing utcTimestamp to datetime if needed
filtered_data["utcTimestamp"] = pd.to_datetime(filtered_data["utcTimestamp"])

# Save to CSV for compatibility with Looker and Power BI
filtered_data.to_csv("cleaned_data.csv", index=True)  # Keep index for the "index" column

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800304 entries, 0 to 800303
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   userId          800304 non-null  int64
#  1   venueCategory   800304 non-null  object
#  2   latitude        800304 non-null  float64
#  3   longitude       800304 non-null  float64
#  4   timezoneOffset  800304 non-null  int64
#  5   utcTimestamp    800304 non-null  datetime64[ns, UTC]
#  6   Year            800304 non-null  int32
#  7   Month           800304 non-null  int32
#  8   Hour            800304 non-null  int32
#  9   city            800304 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(2), int32(3), int64(2), object(2)
# memory usage: 51.9+ MB

# %%
from google.colab import files

# %%
filtered_data.to_csv('filtered_data_tokyo_newyork_2.csv')
files.download('filtered_data_tokyo_newyork_2.csv')
